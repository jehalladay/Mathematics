# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def first_order_ode(f, y0, t):
    y = np.zeros(len(t))
    y[0] = y0
    for n in range(0,len(t)-1):
        y[n+1] = y[n] + f(y[n],t[n])*(t[n+1] - t[n])
    return y

# %%
def second_order_ode(f, y0, dy0, t):
    y = np.zeros(len(t))
    dt = (t[1] - t[0])
    y[0] = y0
    y[1] = dy0*dt+y0
    for n in range(0,len(t)-2):
        y[n+2] = (2 * y[n+1]) - y[n] + f(y[n], (y[n+1]-y[n])/dt, t[n])*(dt**2)
        'y[n+2] = y[n+1] + .5*H(3f(y[n+1], (y[n-1]-y[n])/dt, t[n]) - f(y[n], (y[n-1]-y[n])/dt, t[n]))'
    return y

# %%
g = lambda t: t**2/2+t+3/2
f = lambda y, t: t+1

# %%
t=np.linspace(1,21,40)
y0 = 3
y = first_order_ode(f, y0, t)
y_true = g(t)
plt.plot(t,y,'b.-',t,y_true,'r-')
plt.legend(['Approx','Actual'])
plt.axis([0,12,0,80])
plt.grid(True)
plt.title("Solution of $y'=x+1 , y(1)=3$")
plt.show()

# %%
g = lambda t: np.exp(-2*t) + (2 * np.exp((3/2)*t))
f = lambda y, dy, t: (3*y)-(.5*dy)
y0 = 3
dy0 = 1

# %%
t=np.linspace(0,3,30)
y = second_order_ode(f, y0, dy0, t)
y_true = g(t)
plt.plot(t,y,'b.-',t,y_true,'r-')
plt.legend(['Approx','Actual'])
plt.axis([0,3,0,180])
plt.grid(True)
plt.title("Solution of $y''=3*y-.5*y', y(0)=3, y'(0)=1$")
plt.show()
